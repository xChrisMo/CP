# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/chrismo/Documents/UdaCSP'

# %%
df = pd.read_excel('excelfiles/DIAS Attributes - Values 2017.xlsx')

# %%
df.head(10)
# Out:
#    Unnamed: 0            Unnamed: 1  \
# 0         NaN             Attribute
# 1         NaN              AGER_TYP
# 2         NaN                   NaN
# 3         NaN                   NaN
# 4         NaN                   NaN
# 5         NaN                   NaN
# 6         NaN  ALTERSKATEGORIE_GROB
# 7         NaN                   NaN
# 8         NaN                   NaN
# 9         NaN                   NaN
#
#                                      Unnamed: 2 Unnamed: 3  \
# 0                                   Description      Value
# 1                            best-ager typology         -1
# 2                                           NaN          0
# 3                                           NaN          1
# 4                                           NaN          2
# 5                                           NaN          3
# 6  age classification through prename analysis       -1, 0
# 7                                           NaN          1
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#      Unnamed: 1          Unnamed: 2 Unnamed: 3                  Unnamed: 4
# 0     Attribute         Description      Value                     Meaning
# 1      AGER_TYP  best-ager typology         -1                     unknown
# 2           NaN                 NaN          0  no classification possible
# 3           NaN                 NaN          1             passive elderly
# 4           NaN                 NaN          2            cultural elderly
# ...         ...                 ...        ...                         ...
# 2254        NaN                 NaN          2                       smart
# 2255        NaN                 NaN          3               fair supplied
# 2256        NaN                 NaN          4                price driven
# 2257        NaN                 NaN          5         seeking orientation
# 2258        NaN                 NaN          6                 indifferent
#
# [2259 rows x 4 columns]

# %%
kd = df.groupby('Unnamed: 1').max()

# %%
kd.head(20)
# Out:
#                                                              Unnamed: 2  \
# Unnamed: 1
# AGER_TYP                                             best-ager typology
# ALTERSKATEGORIE_GROB       age classification through prename analysis
# ALTER_HH                                  main age within the household
# ANREDE_KZ                                                        gender
# ANZ_HAUSHALTE_AKTIV                number of households in the building
# ANZ_HH_TITEL                number of academic title holder in building
# ANZ_PERSONEN                   number of adult persons in the household
# ANZ_TITEL             number of professional title holder in household
# Attribute                                                   Description
# BALLRAUM                                 distance to next urban centre
# BIP_FLAG              business-flag indicating companies in the buil...
# CAMEO_DEUG_2015                  CAMEO classification 2015 - Uppergroup
# ...

# %%
new_df = kd[kd['Unnamed: 4'].str.contains('unknown')]

# %%
new_df = new_df.reset_index(drop=False)

# %%
new_df
# Out:
#                Unnamed: 1                                         Unnamed: 2  \
# 0                AGER_TYP                                 best-ager typology
# 1    ALTERSKATEGORIE_GROB       age classification through prename analysis
# 2                ALTER_HH                      main age within the household
# 3               ANREDE_KZ                                             gender
# 4                BALLRAUM                     distance to next urban centre
# ..                    ...                                                ...
# 226    WACHSTUMSGEBIET_NB  growing area (population growth in the last 5 ...
# 227        WOHNDAUER_2008                                length of residence
# 228              WOHNLAGE                                  residential-area
# 229        W_KEIT_KIND_HH    likelihood of a child present in this household
# 230              ZABEOTYP                   typification of energy consumers
#
# ...

# %%
new_df.to_csv('feature_info.csv', index=False)
